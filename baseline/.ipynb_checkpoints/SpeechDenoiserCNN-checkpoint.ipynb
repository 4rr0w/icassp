# %%
import tensorflow as tf
# Out:
# 2023-01-17 19:19:41.959326: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-17 19:19:42.088904: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-17 19:19:42.088924: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-01-17 19:19:42.690567: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-17 19:19:42.690613: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-17 19:19:42.690620: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
import librosa
import pandas as pd
import os
import datetime
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import IPython.display as ipd
import librosa.display
import scipy
import glob
import numpy as np
import math
import warnings
import pickle
from sklearn.utils import shuffle
import zipfile
# Load the TensorBoard notebook extension.
# %load_ext tensorboard

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# 2023-01-17 19:20:14.912480: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-17 19:20:19.333726: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-01-17 19:20:19.333775: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aspire
# 2023-01-17 19:20:19.333781: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aspire
# 2023-01-17 19:20:19.333975: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 525.60.11
# 2023-01-17 19:20:19.334001: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: NOT_FOUND: could not find kernel module information in driver version file contents: "NVRM version: NVIDIA UNIX Open Kernel Module for x86_64  525.60.11  Release Build  (dvs-builder@U16-T01-9-2)  Wed Nov 23 23:04:11 UTC 2022
# GCC version:  gcc version 11.3.0 (Ubuntu 11.3.0-1ubuntu1~22.04)
# "
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 7582555858532963735
#  xla_global_id: -1]

# %%
tf.random.set_seed(999)
np.random.seed(999)

# %%
# !wget 'cdn.daitan.com/dataset.zip'
# Out:
# --2023-01-17 19:20:26--  http://cdn.daitan.com/dataset.zip
# Resolving cdn.daitan.com (cdn.daitan.com)... failed: Name or service not known.
# wget: unable to resolve host address ‘cdn.daitan.com’

# %%
dataset_file_name = './dataset.zip'
with zipfile.ZipFile(dataset_file_name, 'r') as zip_ref:
    zip_ref.extractall('./dataset')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 dataset_file_name = './dataset.zip'
# ----> 2 with zipfile.ZipFile(dataset_file_name, 'r') as zip_ref:
#       3     zip_ref.extractall('./dataset')
#
# File /usr/lib/python3.10/zipfile.py:1249, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1247 while True:
#    1248     try:
# -> 1249         self.fp = io.open(file, filemode)
#    1250     except OSError:
#    1251         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: './dataset.zip'

# %%
path_to_dataset = "../../data/clarity_CEC2_data/clarity_data/dev/scenes/"

# %%
# get training and validation tf record file names
train_tfrecords_filenames = glob.glob(os.path.join(path_to_dataset, '*_mix_CH1*'))[:100]


val_tfrecords_filenames = glob.glob(os.path.join(path_to_dataset, '*_target_CH1*'))[:100]

# suffle the file names for training
np.random.shuffle(train_tfrecords_filenames)
print("Training file names: ", train_tfrecords_filenames)
print("Validation file names: ", val_tfrecords_filenames)
# Out:
# Training file names:  ['../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06429_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08042_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07966_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08129_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07290_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06957_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07866_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07190_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06156_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06587_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07734_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08345_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07103_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06687_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08451_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06857_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06680_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06005_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08204_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06934_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07538_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07073_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08192_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07874_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07941_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06906_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06792_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07841_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07527_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06678_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06112_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06066_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08194_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08033_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06690_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06937_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06933_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07629_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06720_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06898_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07274_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06365_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06013_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06257_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08276_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06637_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07286_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07003_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07391_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06971_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06089_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06664_mix_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06953_mix_CH1.wav', '. ...
# Validation file names:  ['../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06437_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07983_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07270_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07773_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06900_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07610_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07001_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07982_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07447_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07033_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07806_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07375_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08409_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08357_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06176_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07152_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07164_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07148_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07461_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08077_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07533_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06613_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06488_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08091_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07635_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07194_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06191_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06876_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07118_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06446_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06608_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07289_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07225_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07231_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06268_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06589_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07668_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07125_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07296_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07207_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07796_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06984_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07667_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06752_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06704_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S07629_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06085_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08405_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08276_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S06875_target_CH1.wav', '../../data/clarity_CEC2_data/clarity_data/dev/scenes/S08404_target_CH1.wav ...

# %%
windowLength = 256
overlap      = round(0.25 * windowLength) # overlap of 75%
ffTLength    = windowLength
inputFs      = 48e3
fs           = 16e3
numFeatures  = ffTLength//2 + 1
numSegments  = 8
print("windowLength:",windowLength)
print("overlap:",overlap)
print("ffTLength:",ffTLength)
print("inputFs:",inputFs)
print("fs:",fs)
print("numFeatures:",numFeatures)
print("numSegments:",numSegments)
# Out:
# windowLength: 256
# overlap: 64
# ffTLength: 256
# inputFs: 48000.0
# fs: 16000.0
# numFeatures: 129
# numSegments: 8

# %%
mozilla_basepath = path_to_dataset
UrbanSound8K_basepath = path_to_dataset

# %% [markdown]
# ## Prepare Input features

# %%
def tf_record_parser(record):
    keys_to_features = {
        "noise_stft_phase": tf.io.FixedLenFeature((), tf.string, default_value=""),
        'noise_stft_mag_features': tf.io.FixedLenFeature([], tf.string),
        "clean_stft_magnitude": tf.io.FixedLenFeature((), tf.string)
    }

    features = tf.io.parse_single_example(record, keys_to_features)

    noise_stft_mag_features = tf.io.decode_raw(features['noise_stft_mag_features'], tf.float32)
    clean_stft_magnitude = tf.io.decode_raw(features['clean_stft_magnitude'], tf.float32)
    noise_stft_phase = tf.io.decode_raw(features['noise_stft_phase'], tf.float32)

    # reshape input and annotation images
    noise_stft_mag_features = tf.reshape(noise_stft_mag_features, (129, 8, 1), name="noise_stft_mag_features")
    clean_stft_magnitude = tf.reshape(clean_stft_magnitude, (129, 1, 1), name="clean_stft_magnitude")
    noise_stft_phase = tf.reshape(noise_stft_phase, (129,), name="noise_stft_phase")

    return noise_stft_mag_features, clean_stft_magnitude

# %% [markdown]
# ## Create tf.Data.Dataset

# %%
from data_processing.mozilla_common_voice import MozillaCommonVoiceDataset
from data_processing.urban_sound_8K import UrbanSound8K
from data_processing.dataset import Dataset
import warnings

warnings.filterwarnings(action='ignore')

windowLength = 256
config = {'windowLength': windowLength,
          'overlap': round(0.25 * windowLength),
          'fs': 16000,
          'audio_max_duration': 0.8}

train_dataset = Dataset(train_tfrecords_filenames, train_tfrecords_filenames, **config)
train_dataset.create_tf_record(prefix='train', subset_size=100)

# train_dataset = Dataset(train_tfrecords_filenames, val_tfrecords_filenames, **config)
# train_dataset.create_tf_record(prefix='train', subset_size=4000)

# ## Create Test Set
# clean_test_filenames = mcv.get_test_filenames()

# noise_test_filenames = us8K.get_test_filenames()

test_dataset = Dataset(val_tfrecords_filenames, val_tfrecords_filenames, **config)
test_dataset.create_tf_record(prefix='test', subset_size=100, parallel=False)
# Out:
# Skipping ./records/train_0.tfrecords
# Processing files from: 0 to 100

# %%
train_dataset = tf.data.TFRecordDataset(['./records/train_0.tfrecords'])
train_dataset = train_dataset.map(tf_record_parser)
train_dataset = train_dataset.shuffle(8192)
train_dataset = train_dataset.repeat()
train_dataset = train_dataset.batch(512)
train_dataset = train_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
test_dataset = tf.data.TFRecordDataset(['./records/test_0.tfrecords'])
test_dataset = test_dataset.map(tf_record_parser)
test_dataset = test_dataset.repeat(1)
test_dataset = test_dataset.batch(512)
print(test_dataset)
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 129, 8, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None, 129, 1, 1), dtype=tf.float32, name=None))>

# %% [markdown]
# ## Model Training

# %%
from tensorflow.keras.layers import Conv2D, Input, LeakyReLU, Flatten, Dense, Reshape, Conv2DTranspose, BatchNormalization, Activation
from tensorflow.keras import Model, Sequential

# %%
def conv_block(x, filters, kernel_size, strides, padding='same', use_bn=True):
  x = Conv2D(filters=filters, kernel_size=kernel_size, strides=strides, padding=padding, use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(0.0006))(x)
  x = Activation('relu')(x)
  if use_bn:
    x = BatchNormalization()(x)
  return x

# %%
def full_pre_activation_block(x, filters, kernel_size, strides, padding='same', use_bn=True):
  shortcut = x
  in_channels = x.shape[-1]

  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = Conv2D(filters=filters, kernel_size=kernel_size, strides=strides, padding='same')(x)

  x = BatchNormalization()(x)
  x = Activation('relu')(x)
  x = Conv2D(filters=in_channels, kernel_size=kernel_size, strides=strides, padding='same')(x)

  return shortcut + x

# %%
def build_model(l2_strength):
  inputs = Input(shape=[numFeatures,numSegments,1])
  x = inputs

  # -----
  x = tf.keras.layers.ZeroPadding2D(((4,4), (0,0)))(x)
  x = Conv2D(filters=18, kernel_size=[9,8], strides=[1, 1], padding='valid', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(x)
  x = BatchNormalization()(x)

  skip0 = Conv2D(filters=30, kernel_size=[5,1], strides=[1, 1], padding='same', use_bias=False,
                 kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(skip0)
  x = BatchNormalization()(x)

  x = Conv2D(filters=8, kernel_size=[9,1], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(x)
  x = BatchNormalization()(x)

  # -----
  x = Conv2D(filters=18, kernel_size=[9,1], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(x)
  x = BatchNormalization()(x)

  skip1 = Conv2D(filters=30, kernel_size=[5,1], strides=[1, 1], padding='same', use_bias=False,
                 kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(skip1)
  x = BatchNormalization()(x)

  x = Conv2D(filters=8, kernel_size=[9,1], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(x)
  x = BatchNormalization()(x)

  # ----
  x = Conv2D(filters=18, kernel_size=[9,1], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(x)
  x = BatchNormalization()(x)
  
  x = Conv2D(filters=30, kernel_size=[5,1], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(x)
  x = BatchNormalization()(x)

  x = Conv2D(filters=8, kernel_size=[9,1], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(x)
  x = BatchNormalization()(x)

  # ----
  x = Conv2D(filters=18, kernel_size=[9,1], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(x)
  x = BatchNormalization()(x)

  x = Conv2D(filters=30, kernel_size=[5,1], strides=[1, 1], padding='same', use_bias=False,
             kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = x + skip1
  x = Activation('relu')(x)
  x = BatchNormalization()(x)

  x = Conv2D(filters=8, kernel_size=[9,1], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(x)
  x = BatchNormalization()(x)

  # ----
  x = Conv2D(filters=18, kernel_size=[9,1], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(x)
  x = BatchNormalization()(x)

  x = Conv2D(filters=30, kernel_size=[5,1], strides=[1, 1], padding='same', use_bias=False,
             kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = x + skip0
  x = Activation('relu')(x)
  x = BatchNormalization()(x)

  x = Conv2D(filters=8, kernel_size=[9,1], strides=[1, 1], padding='same', use_bias=False,
              kernel_regularizer=tf.keras.regularizers.l2(l2_strength))(x)
  x = Activation('relu')(x)
  x = BatchNormalization()(x)

  # ----
  x = tf.keras.layers.SpatialDropout2D(0.2)(x)
  x = Conv2D(filters=1, kernel_size=[129,1], strides=[1, 1], padding='same')(x)

  model = Model(inputs=inputs, outputs=x)

  optimizer = tf.keras.optimizers.Adam(3e-4)
  #optimizer = RAdam(total_steps=10000, warmup_proportion=0.1, min_lr=3e-4)

  model.compile(optimizer=optimizer, loss='mse', 
                metrics=[tf.keras.metrics.RootMeanSquaredError('rmse')])
  return model

# %%
model = build_model(l2_strength=0.0)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 129, 8, 1)]  0           []
#
#  zero_padding2d_2 (ZeroPadding2  (None, 137, 8, 1)   0           ['input_3[0][0]']
#  D)
#
#  conv2d_32 (Conv2D)             (None, 129, 1, 18)   1296        ['zero_padding2d_2[0][0]']
#
#  activation_30 (Activation)     (None, 129, 1, 18)   0           ['conv2d_32[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 129, 1, 18)  72          ['activation_30[0][0]']
#  ormalization)
#
#  conv2d_33 (Conv2D)             (None, 129, 1, 30)   2700        ['batch_normalization_30[0][0]']
#
#  activation_31 (Activation)     (None, 129, 1, 30)   0           ['conv2d_33[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 129, 1, 30)  120         ['activation_31[0][0]']
#  ormalization)
#
#  conv2d_34 (Conv2D)             (None, 129, 1, 8)    2160        ['batch_normalization_31[0][0]']
#
#  activation_32 (Activation)     (None, 129, 1, 8)    0           ['conv2d_34[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 129, 1, 8)   32          ['activation_32[0][0]']
#  ormalization)
#
#  conv2d_35 (Conv2D)             (None, 129, 1, 18)   1296        ['batch_normalization_32[0][0]']
#
#  activation_33 (Activation)     (None, 129, 1, 18)   0           ['conv2d_35[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 129, 1, 18)  72          ['activation_33[0][0]']
#  ormalization)
#
#  conv2d_36 (Conv2D)             (None, 129, 1, 30)   2700        ['batch_normalization_33[0][0]']
#
#  activation_34 (Activation)     (None, 129, 1, 30)   0           ['conv2d_36[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 129, 1, 30)  120         ['activation_34[0][0]']
#  ormalization)
#
#  conv2d_37 (Conv2D)             (None, 129, 1, 8)    2160        ['batch_normalization_34[0][0]']
#
#  activation_35 (Activation)     (None, 129, 1, 8)    0           ['conv2d_37[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 129, 1, 8)   32          ['activation_35[0][0]']
#  ormalization)
#
#  conv2d_38 (Conv2D)             (None, 129, 1, 18)   1296        ['batch_normalization_35[0][0]']
#
#  activation_36 (Activation)     (None, 129, 1, 18)   0           ['conv2d_38[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 129, 1, 18)  72          ['activation_36[0][0]']
#  ormalization)
#
#  conv2d_39 (Conv2D)             (None, 129, 1, 30)   2700        ['batch_normalization_36[0][0]']
#
#  activation_37 (Activation)     (None, 129, 1, 30)   0           ['conv2d_39[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 129, 1, 30)  120         ['activation_37[0][0]']
#  ormalization)
#
#  conv2d_40 (Conv2D)             (None, 129, 1, 8)    2160        ['batch_normalization_37[0][0]']
#
#  activation_38 (Activation)     (None, 129, 1, 8)    0           ['conv2d_40[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 129, 1, 8)   32          ['activation_38[0][0]']
#  ormalization)
#
#  conv2d_41 (Conv2D)             (None, 129, 1, 18)   1296        ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 129, 1, 18)   0           ['conv2d_41[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 129, 1, 18)  72          ['activation_39[0][0]']
#  ormalization)
#
#  conv2d_42 (Conv2D)             (None, 129, 1, 30)   2700        ['batch_normalization_39[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 129, 1, 30)  0           ['conv2d_42[0][0]',
#  mbda)                                                            'conv2d_36[0][0]']
#  activation_40 (Activation)     (None, 129, 1, 30)   0           ['tf.__operators__.add_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 129, 1, 30)  120         ['activation_40[0][0]']
#  ormalization)
#
#  conv2d_43 (Conv2D)             (None, 129, 1, 8)    2160        ['batch_normalization_40[0][0]']
#
#  activation_41 (Activation)     (None, 129, 1, 8)    0           ['conv2d_43[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 129, 1, 8)   32          ['activation_41[0][0]']
#  ormalization)
#
#  conv2d_44 (Conv2D)             (None, 129, 1, 18)   1296        ['batch_normalization_41[0][0]']
#
#  activation_42 (Activation)     (None, 129, 1, 18)   0           ['conv2d_44[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 129, 1, 18)  72          ['activation_42[0][0]']
#  ormalization)
#
#  conv2d_45 (Conv2D)             (None, 129, 1, 30)   2700        ['batch_normalization_42[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 129, 1, 30)  0           ['conv2d_45[0][0]',
#  mbda)                                                            'conv2d_33[0][0]']
#
#  activation_43 (Activation)     (None, 129, 1, 30)   0           ['tf.__operators__.add_5[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 129, 1, 30)  120         ['activation_43[0][0]']
#  ormalization)
#
#  conv2d_46 (Conv2D)             (None, 129, 1, 8)    2160        ['batch_normalization_43[0][0]']
#
#  activation_44 (Activation)     (None, 129, 1, 8)    0           ['conv2d_46[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 129, 1, 8)   32          ['activation_44[0][0]']
#  ormalization)
#
#  spatial_dropout2d_2 (SpatialDr  (None, 129, 1, 8)   0           ['batch_normalization_44[0][0]']
#  opout2D)
#
#  conv2d_47 (Conv2D)             (None, 129, 1, 1)    1033        ['spatial_dropout2d_2[0][0]']
#
# ==================================================================================================
# Total params: 32,933
# Trainable params: 32,373
# Non-trainable params: 560
# __________________________________________________________________________________________________

# %%
# You might need to install the following dependencies: sudo apt install python-pydot python-pydot-ng graphviz
tf.keras.utils.plot_model(model, show_shapes=True, dpi=64)

# %%
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-390ff88d6707f90a" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-390ff88d6707f90a");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
baseline_val_loss = model.evaluate(test_dataset)
print(f"Baseline accuracy {baseline_val_loss}")
# Out:
# ---------------------------------------------------------------------------
# DataLossError                             Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 baseline_val_loss = model.evaluate(test_dataset)
#       2 print(f"Baseline accuracy {baseline_val_loss}")
#
# File ~/Desktop/venv/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/Desktop/venv/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# DataLossError: Graph execution error:
#
# Detected at node 'IteratorGetNext' defined at (most recent call last):
#     File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/traitlets/config/application.py", line 1041, in launch_instance
#       app.start()
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 724, in start
#       self.io_loop.start()
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 512, in dispatch_queue
#       await self.process_one()
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 501, in process_one
#       await dispatch(*args)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 408, in dispatch_shell
#       await result
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 731, in execute_request
#       reply_content = await reply_content
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 417, in do_execute
#       res = shell.run_cell(
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2945, in run_cell
#       result = self._run_cell(
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3000, in _run_cell
#       return runner(coro)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3203, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3382, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3442, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_115297/2321405833.py", line 1, in <module>
#       baseline_val_loss = model.evaluate(test_dataset)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/keras/engine/training.py", line 2040, in evaluate
#       tmp_logs = self.test_function(iterator)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/keras/engine/training.py", line 1820, in test_function
#       return step_function(self, iterator)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/keras/engine/training.py", line 1803, in step_function
#       data = next(iterator)
# Node: 'IteratorGetNext'
# corrupted record at 0 (Is this even a TFRecord file?)
# 	 [[{{node IteratorGetNext}}]] [Op:__inference_test_function_10052]

# %%
def l2_norm(vector):
    return np.square(vector)

def SDR(denoised, cleaned, eps=1e-7): # Signal to Distortion Ratio
    a = l2_norm(denoised)
    b = l2_norm(denoised - cleaned)
    a_b = a / b
    return np.mean(10 * np.log10(a_b + eps))

# %%
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True, baseline=None)

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, update_freq='batch')
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath='./denoiser_cnn_log_mel_generator.h5', 
                                                         monitor='val_loss', save_best_only=True)

model.fit(train_dataset,
         steps_per_epoch=50, # you might need to change this
         validation_data=test_dataset,
         epochs=400,
         callbacks=[early_stopping_callback, tensorboard_callback, checkpoint_callback]
        )
# Out:
# Epoch 1/400
# ---------------------------------------------------------------------------
# DataLossError                             Traceback (most recent call last)
# Cell In[36], line 8
#       4 tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, update_freq='batch')
#       5 checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath='./denoiser_cnn_log_mel_generator.h5',
#       6                                                          monitor='val_loss', save_best_only=True)
# ----> 8 model.fit(train_dataset,
#       9          steps_per_epoch=50, # you might need to change this
#      10          validation_data=test_dataset,
#      11          epochs=400,
#      12          callbacks=[early_stopping_callback, tensorboard_callback, checkpoint_callback]
#      13         )
#
# File ~/Desktop/venv/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/Desktop/venv/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# DataLossError: Graph execution error:
#
# Detected at node 'IteratorGetNext' defined at (most recent call last):
#     File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/traitlets/config/application.py", line 1041, in launch_instance
#       app.start()
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 724, in start
#       self.io_loop.start()
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 512, in dispatch_queue
#       await self.process_one()
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 501, in process_one
#       await dispatch(*args)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 408, in dispatch_shell
#       await result
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 731, in execute_request
#       reply_content = await reply_content
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 417, in do_execute
#       res = shell.run_cell(
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2945, in run_cell
#       result = self._run_cell(
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3000, in _run_cell
#       return runner(coro)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3203, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3382, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3442, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_115297/1051592082.py", line 8, in <module>
#       model.fit(train_dataset,
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/keras/engine/training.py", line 1650, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/keras/engine/training.py", line 1249, in train_function
#       return step_function(self, iterator)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/keras/engine/training.py", line 1232, in step_function
#       data = next(iterator)
# Node: 'IteratorGetNext'
# corrupted record at 0 (Is this even a TFRecord file?)
# 	 [[{{node IteratorGetNext}}]] [Op:__inference_train_function_7064]

# %%
val_loss = model.evaluate(test_dataset)[0]
if val_loss < baseline_val_loss:
  print("New model saved.")
  model.save('./denoiser_cnn_log_mel_generator.h5')
# Out:
# ---------------------------------------------------------------------------
# DataLossError                             Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 val_loss = model.evaluate(test_dataset)[0]
#       2 if val_loss < baseline_val_loss:
#       3   print("New model saved.")
#
# File ~/Desktop/venv/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/Desktop/venv/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# DataLossError: Graph execution error:
#
# Detected at node 'IteratorGetNext' defined at (most recent call last):
#     File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#       exec(code, run_globals)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/traitlets/config/application.py", line 1041, in launch_instance
#       app.start()
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 724, in start
#       self.io_loop.start()
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 215, in start
#       self.asyncio_loop.run_forever()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#       self._run_once()
#     File "/usr/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#       handle._run()
#     File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 512, in dispatch_queue
#       await self.process_one()
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 501, in process_one
#       await dispatch(*args)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 408, in dispatch_shell
#       await result
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 731, in execute_request
#       reply_content = await reply_content
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 417, in do_execute
#       res = shell.run_cell(
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2945, in run_cell
#       result = self._run_cell(
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3000, in _run_cell
#       return runner(coro)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3203, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3382, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3442, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_115297/2321405833.py", line 1, in <module>
#       baseline_val_loss = model.evaluate(test_dataset)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/keras/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/keras/engine/training.py", line 2040, in evaluate
#       tmp_logs = self.test_function(iterator)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/keras/engine/training.py", line 1820, in test_function
#       return step_function(self, iterator)
#     File "/home/arrow/Desktop/venv/lib/python3.10/site-packages/keras/engine/training.py", line 1803, in step_function
#       data = next(iterator)
# Node: 'IteratorGetNext'
# corrupted record at 0 (Is this even a TFRecord file?)
# 	 [[{{node IteratorGetNext}}]] [Op:__inference_test_function_1469]

# %% [markdown]
# ## Testing

# %%
def read_audio(filepath, sample_rate, normalize=True):
    """Read an audio file and return it as a numpy array"""
    audio, sr = librosa.load(filepath, sr=sample_rate)
    if normalize:
      div_fac = 1 / np.max(np.abs(audio)) / 3.0
      audio = audio * div_fac
    return audio, sr
        
def add_noise_to_clean_audio(clean_audio, noise_signal):
    """Adds noise to an audio sample"""
    if len(clean_audio) >= len(noise_signal):
        # print("The noisy signal is smaller than the clean audio input. Duplicating the noise.")
        while len(clean_audio) >= len(noise_signal):
            noise_signal = np.append(noise_signal, noise_signal)

    ## Extract a noise segment from a random location in the noise file
    ind = np.random.randint(0, noise_signal.size - clean_audio.size)

    noiseSegment = noise_signal[ind: ind + clean_audio.size]

    speech_power = np.sum(clean_audio ** 2)
    noise_power = np.sum(noiseSegment ** 2)
    noisyAudio = clean_audio + np.sqrt(speech_power / noise_power) * noiseSegment
    return noisyAudio

def play(audio, sample_rate):
    ipd.display(ipd.Audio(data=audio, rate=sample_rate))  # load a local WAV file

# %%
class FeatureExtractor:
    def __init__(self, audio, *, windowLength, overlap, sample_rate):
        self.audio = audio
        self.ffT_length = windowLength
        self.window_length = windowLength
        self.overlap = overlap
        self.sample_rate = sample_rate
        self.window = scipy.signal.hamming(self.window_length, sym=False)

    def get_stft_spectrogram(self):
        return librosa.stft(self.audio, n_fft=self.ffT_length, win_length=self.window_length, hop_length=self.overlap,
                            window=self.window, center=True)

    def get_audio_from_stft_spectrogram(self, stft_features):
        return librosa.istft(stft_features, win_length=self.window_length, hop_length=self.overlap,
                             window=self.window, center=True)

    def get_mel_spectrogram(self):
        return librosa.feature.melspectrogram(self.audio, sr=self.sample_rate, power=2.0, pad_mode='reflect',
                                           n_fft=self.ffT_length, hop_length=self.overlap, center=True)

    def get_audio_from_mel_spectrogram(self, M):
        return librosa.feature.inverse.mel_to_audio(M, sr=self.sample_rate, n_fft=self.ffT_length, hop_length=self.overlap,
                                             win_length=self.window_length, window=self.window,
                                             center=True, pad_mode='reflect', power=2.0, n_iter=32, length=None)

# %%
cleanAudio, sr = read_audio(os.path.join(mozilla_basepath, 'test', 'common_voice_en_16526.mp3'), sample_rate=fs)
print("Min:", np.min(cleanAudio),"Max:",np.max(cleanAudio))
ipd.Audio(data=cleanAudio, rate=sr) # load a local WAV file
# Out:
# /home/arrow/Desktop/venv/lib/python3.10/site-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File ~/Desktop/venv/lib/python3.10/site-packages/librosa/core/audio.py:164, in load(path, sr, mono, offset, duration, dtype, res_type)
#     163 try:
# --> 164     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     166 except RuntimeError as exc:
#     167     # If soundfile failed, try audioread instead
#
# File ~/Desktop/venv/lib/python3.10/site-packages/librosa/core/audio.py:195, in __soundfile_load(path, offset, duration, dtype)
#     193 else:
#     194     # Otherwise, create the soundfile object
# --> 195     context = sf.SoundFile(path)
#     197 with context as sf_desc:
#
# File ~/Desktop/venv/lib/python3.10/site-packages/soundfile.py:655, in SoundFile.__init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     653 self._info = _create_info_struct(file, mode, samplerate, channels,
#     654                                  format, subtype, endian)
# --> 655 self._file = self._open(file, mode_int, closefd)
#     656 if set(mode).issuperset('r+') and self.seekable():
#     657     # Move write position to 0 (like in Python file objects)
#
# File ~/Desktop/venv/lib/python3.10/site-packages/soundfile.py:1213, in SoundFile._open(self, file, mode_int, closefd)
#    1212     err = _snd.sf_error(file_ptr)
# -> 1213     raise LibsndfileError(err, prefix="Error opening {0!r}: ".format(self.name))
#    1214 if mode_int == _snd.SFM_WRITE:
#    1215     # Due to a bug in libsndfile version <= 1.0.25, frames != 0
#    1216     # when opening a named pipe in SFM_WRITE mode.
#    1217     # See http://github.com/erikd/libsndfile/issues/77.
#
# LibsndfileError: Error opening './dataset/en/test/common_voice_en_16526.mp3': System error.
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 cleanAudio, sr = read_audio(os.path.join(mozilla_basepath, 'test', 'common_voice_en_16526.mp3'), sample_rate=fs)
#       2 print("Min:", np.min(cleanAudio),"Max:",np.max(cleanAudio))
#       3 ipd.Audio(data=cleanAudio, rate=sr) # load a local WAV file
#
# Cell In[37], line 3, in read_audio(filepath, sample_rate, normalize)
#       1 def read_audio(filepath, sample_rate, normalize=True):
#       2     """Read an audio file and return it as a numpy array"""
# ----> 3     audio, sr = librosa.load(filepath, sr=sample_rate)
#       4     if normalize:
#       5       div_fac = 1 / np.max(np.abs(audio)) / 3.0
#
# File ~/Desktop/venv/lib/python3.10/site-packages/librosa/util/decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File ~/Desktop/venv/lib/python3.10/site-packages/librosa/core/audio.py:170, in load(path, sr, mono, offset, duration, dtype, res_type)
#     168 if isinstance(path, (str, pathlib.PurePath)):
#     169     warnings.warn("PySoundFile failed. Trying audioread instead.", stacklevel=2)
# --> 170     y, sr_native = __audioread_load(path, offset, duration, dtype)
#     171 else:
#     172     raise exc
#
# File ~/Desktop/venv/lib/python3.10/site-packages/librosa/core/audio.py:226, in __audioread_load(path, offset, duration, dtype)
#     223     reader = path
#     224 else:
#     225     # If the input was not an audioread object, try to open it
# --> 226     reader = audioread.audio_open(path)
#     228 with reader as input_file:
#     229     sr_native = input_file.samplerate
#
# File ~/Desktop/venv/lib/python3.10/site-packages/audioread/__init__.py:127, in audio_open(path, backends)
#     125 for BackendClass in backends:
#     126     try:
# --> 127         return BackendClass(path)
#     128     except DecodeError:
#     129         pass
#
# File ~/Desktop/venv/lib/python3.10/site-packages/audioread/rawread.py:59, in RawAudioFile.__init__(self, filename)
#      58 def __init__(self, filename):
# ---> 59     self._fh = open(filename, 'rb')
#      61     try:
#      62         self._file = aifc.open(self._fh)
#
# FileNotFoundError: [Errno 2] No such file or directory: './dataset/en/test/common_voice_en_16526.mp3'

# %%
noiseAudio, sr = read_audio(os.path.join(UrbanSound8K_basepath, 'test', '7913-3-0-0.wav'), sample_rate=fs)
print("Min:", np.min(noiseAudio),"Max:",np.max(noiseAudio))
ipd.Audio(data=noiseAudio, rate=sr) # load a local WAV file

# %%
cleanAudioFeatureExtractor = FeatureExtractor(cleanAudio, windowLength=windowLength, overlap=overlap, sample_rate=sr)
stft_features = cleanAudioFeatureExtractor.get_stft_spectrogram()
stft_features = np.abs(stft_features)
print("Min:", np.min(stft_features),"Max:",np.max(stft_features))

# %%
noisyAudio = add_noise_to_clean_audio(cleanAudio, noiseAudio)
ipd.Audio(data=noisyAudio, rate=fs) # load a local WAV file

# %%
def prepare_input_features(stft_features):
    # Phase Aware Scaling: To avoid extreme differences (more than
    # 45 degree) between the noisy and clean phase, the clean spectral magnitude was encoded as similar to [21]:
    noisySTFT = np.concatenate([stft_features[:,0:numSegments-1], stft_features], axis=1)
    stftSegments = np.zeros((numFeatures, numSegments , noisySTFT.shape[1] - numSegments + 1))

    for index in range(noisySTFT.shape[1] - numSegments + 1):
        stftSegments[:,:,index] = noisySTFT[:,index:index + numSegments]
    return stftSegments

# %%
noiseAudioFeatureExtractor = FeatureExtractor(noisyAudio, windowLength=windowLength, overlap=overlap, sample_rate=sr)
noise_stft_features = noiseAudioFeatureExtractor.get_stft_spectrogram()

# Paper: Besides, spectral phase was not used in the training phase.
# At reconstruction, noisy spectral phase was used instead to
# perform in- verse STFT and recover human speech.
noisyPhase = np.angle(noise_stft_features)
print(noisyPhase.shape)
noise_stft_features = np.abs(noise_stft_features)

mean = np.mean(noise_stft_features)
std = np.std(noise_stft_features)
noise_stft_features = (noise_stft_features - mean) / std

# %%
predictors = prepare_input_features(noise_stft_features)

# %%
predictors = np.reshape(predictors, (predictors.shape[0], predictors.shape[1], 1, predictors.shape[2]))
predictors = np.transpose(predictors, (3, 0, 1, 2)).astype(np.float32)
print('predictors.shape:', predictors.shape)

# %%
STFTFullyConvolutional = model.predict(predictors)
print(STFTFullyConvolutional.shape)

# %%
def revert_features_to_audio(features, phase, cleanMean=None, cleanStd=None):
    # scale the outpus back to the original range
    if cleanMean and cleanStd:
        features = cleanStd * features + cleanMean

    phase = np.transpose(phase, (1, 0))
    features = np.squeeze(features)

    # features = librosa.db_to_power(features)
    features = features * np.exp(1j * phase)  # that fixes the abs() ope previously done

    features = np.transpose(features, (1, 0))
    return noiseAudioFeatureExtractor.get_audio_from_stft_spectrogram(features)

# %%
denoisedAudioFullyConvolutional = revert_features_to_audio(STFTFullyConvolutional, noisyPhase, mean, std)
print("Min:", np.min(denoisedAudioFullyConvolutional),"Max:",np.max(denoisedAudioFullyConvolutional))
ipd.Audio(data=denoisedAudioFullyConvolutional, rate=fs) # load a local WAV file

# %%
# A numeric identifier of the sound class -- Types of noise
# 0 = air_conditioner
# 1 = car_horn
# 2 = children_playing
# 3 = dog_bark
# 4 = drilling
# 5 = engine_idling
# 6 = gun_shot
# 7 = jackhammer
# 8 = siren
# 9 = street_music

# %%
f, (ax1, ax2, ax3) = plt.subplots(3, 1, sharey=True)

ax1.plot(cleanAudio)
ax1.set_title("Clean Audio")

ax2.plot(noisyAudio)
ax2.set_title("Noisy Audio")

ax3.plot(denoisedAudioFullyConvolutional)
ax3.set_title("Denoised Audio")
