# %%
import librosa
import numpy as np
import math
from baseline.cnn.data_processing.feature_extractor import FeatureExtractor
from baseline.cnn.utils import prepare_input_features, get_tf_feature, read_audio
import multiprocessing
import os
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %%
 path_to_scene_files = "../../clarity_CEC2_data_train/clarity_data/train/scenes/"

# %%
import warnings
import numpy as np
import glob
import os
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
import matplotlib.pyplot as plt
import IPython.display as ipd
import librosa.display

# %%
# get training and validation file names
scene_filenames = glob.glob(os.path.join(path_to_scene_files, '*_hr.wav'))

# %%
file = scene_filenames[0]
clean_filename = file.replace("_hr", "_target_anechoic_CH1")
interferer_filename = file.replace("_hr", "_interferer_CH1")
mix_filename = file.replace("_hr", "_mix_CH1")
print(clean_filename)
print(mix_filename)
print(interferer_filename)
# Out:
# ../../clarity_CEC2_data_train/clarity_data/train/scenes\S00001_target_anechoic_CH1.wav
# ../../clarity_CEC2_data_train/clarity_data/train/scenes\S00001_mix_CH1.wav
# ../../clarity_CEC2_data_train/clarity_data/train/scenes\S00001_interferer_CH1.wav

# %%
sr = 44100
windowLength = 256
overlap = round(0.25 * windowLength)

clean, sr = read_audio(clean_filename, sr)
noise, sr = read_audio(interferer_filename, sr)
mix, sr = read_audio(mix_filename, sr)

# %%
ipd.Audio(data=clean, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(data=noise, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(data=mix, rate=sr)
# Out:
# (240844,)

# %%
fig = plt.figure(figsize=(10, 1))
rows = 1
col = 3

fig.add_subplot(rows, col, 1)
plt.plot(clean)

fig.add_subplot(rows, col, 2)
plt.plot(noise)

fig.add_subplot(rows, col, 3)
plt.plot(mix)

plt.show()

# %%
clean_input_fe = FeatureExtractor(clean, 
                                  windowLength=windowLength, 
                                  overlap=overlap,
                                  sample_rate=sr)
noise_input_fe = FeatureExtractor(noise, 
                                  windowLength=windowLength, 
                                  overlap=overlap,
                                  sample_rate=sr)
mix_input_fe = FeatureExtractor(mix, 
                                  windowLength=windowLength, 
                                  overlap=overlap,
                                  sample_rate=sr)

# %%
clean_spec = np.abs(clean_input_fe.get_stft_spectrogram())
clean_mel = clean_input_fe.get_mel_spectrogram()

noise_spec = np.abs(noise_input_fe.get_stft_spectrogram())
noise_mel = noise_input_fe.get_mel_spectrogram()

mix_spec = np.abs(mix_input_fe.get_stft_spectrogram())
mix_mel = mix_input_fe.get_mel_spectrogram()

audio_files = [clean, noise, mix]
specs = [clean_spec, noise_spec, mix_spec]
mels = [clean_mel, noise_mel, mix_mel]
# Out:
# C:\Users\arrow\Desktop\venv\icassp\baseline\cnn\data_processing\feature_extractor.py:23: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.feature.melspectrogram(self.audio, sr=self.sample_rate, power=2.0, pad_mode='reflect',

# %%
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(10,7))
for i in range(0, 3):
    librosa.display.waveshow(audio_files[i], sr=sr, ax=ax[0, i]) 
    librosa.display.specshow(specs[i], x_axis='time', ax=ax[1, i])
    librosa.display.specshow(librosa.power_to_db(specs[i]), x_axis='time', y_axis='log', ax=ax[2, i])

# %%
from scipy.fft import rfft, rfftfreq

# %%
fig = plt.figure(figsize=(15, 5))
rows = 1
col = 3

fig.add_subplot(rows, col, 1)
N = len(clean)
print(N)
yf = rfft(clean)
xf = rfftfreq(N, 1 / sr)
plt.plot(np.abs(xf), np.abs(yf))

fig.add_subplot(rows, col, 2)
N = len(noise)
yf = rfft(noise)
xf = rfftfreq(N, 1 / sr)
plt.plot(np.abs(xf), np.abs(yf))

fig.add_subplot(rows, col, 3)
N = len(mix)
yf = rfft(mix)
xf = rfftfreq(N, 1 / sr)

plt.plot(np.abs(xf), np.abs(yf))
plt.show()
# Out:
# 240844

# %%
import noisereduce as nr

# %%
reduced_mix = nr.reduce_noise(y=mix, sr=sr)

reduced_input_fe = FeatureExtractor(reduced_mix, 
                                  windowLength=windowLength, 
                                  overlap=overlap,
                                  sample_rate=sr)

reduced_spec = np.abs(reduced_input_fe.get_stft_spectrogram())
reduced_mel = reduced_input_fe.get_mel_spectrogram()

audio_files.append(reduced_mix)
specs.append(reduced_spec)
mels.append(reduced_mel)

aud = reduced_input_fe.get_audio_from_mel_spectrogram(reduced_mel)

aud_input_fe = FeatureExtractor(aud, 
                                  windowLength=windowLength, 
                                  overlap=overlap,
                                  sample_rate=sr)

aud_spec = np.abs(aud_input_fe.get_stft_spectrogram())
aud_mel = aud_input_fe.get_mel_spectrogram()

audio_files.append(aud)
specs.append(aud_spec)
mels.append(aud_mel)
# Out:
# C:\Users\arrow\Desktop\venv\icassp\baseline\cnn\data_processing\feature_extractor.py:23: FutureWarning: Pass y=[ 2.7904992e-10  2.1739485e-10  1.2748244e-10 ...  5.0287628e-11
#  -8.7875636e-12  2.4588897e-11] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.feature.melspectrogram(self.audio, sr=self.sample_rate, power=2.0, pad_mode='reflect',

# %%
fig, ax = plt.subplots(nrows=3, ncols=5, figsize=(10,7))
for i in range(0, 5):
    librosa.display.waveshow(audio_files[i], sr=sr, ax=ax[0,i]) 
    librosa.display.specshow(specs[i], x_axis='time', ax=ax[1, i])
    librosa.display.specshow(librosa.power_to_db(specs[i]), x_axis='time', y_axis='log', ax=ax[2, i])

# %%
from scipy.io import wavfile
print(np.array(reduced_mix.shape), mix.shape)
# Out:
# [240844] (240844,)

# %%
reduced = nr.reduce_noise(y=mix, sr=sr)
denoised = np.column_stack((reduced, reduced))
denoised.shape
# Out:
# (240844, 2)

# %%
wavfile.write(
            './baseline/exp/enhanced_signals/S06001_L0064_enhanced.wav', 
            sr, denoised
        )
ipd.Audio(data=denoised, rate=sr)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17380\3365706814.py in <module>
#       3             sr, denoised
#       4         )
# ----> 5 ipd.Audio(data=denoised, rate=sr)
#
# ~\anaconda3\lib\site-packages\IPython\lib\display.py in __init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     115             if rate is None:
#     116                 raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
# --> 117             self.data = Audio._make_wav(data, rate, normalize)
#     118
#     119     def reload(self):
#
# ~\anaconda3\lib\site-packages\IPython\lib\display.py in _make_wav(data, rate, normalize)
#     147         waveobj.setsampwidth(2)
#     148         waveobj.setcomptype('NONE','NONE')
# --> 149         waveobj.writeframes(scaled)
#     150         val = fp.getvalue()
#     151         waveobj.close()
#
# ~\anaconda3\lib\wave.py in writeframes(self, data)
#     435
#     436     def writeframes(self, data):
# --> 437         self.writeframesraw(data)
#     438         if self._datalength != self._datawritten:
#     439             self._patchheader()
#
# ~\anaconda3\lib\wave.py in writeframesraw(self, data)
#     424         if not isinstance(data, (bytes, bytearray)):
#     425             data = memoryview(data).cast('B')
# --> 426         self._ensure_header_written(len(data))
#     427         nframes = len(data) // (self._sampwidth * self._nchannels)
#     428         if self._convert:
#
# ~\anaconda3\lib\wave.py in _ensure_header_written(self, datasize)
#     465             if not self._framerate:
#     466                 raise Error('sampling rate not specified')
# --> 467             self._write_header(datasize)
#     468
#     469     def _write_header(self, initlength):
#
# ~\anaconda3\lib\wave.py in _write_header(self, initlength)
#     477         except (AttributeError, OSError):
#     478             self._form_length_pos = None
# --> 479         self._file.write(struct.pack('<L4s4sLHHLLHH4s',
#     480             36 + self._datalength, b'WAVE', b'fmt ', 16,
#     481             WAVE_FORMAT_PCM, self._nchannels, self._framerate,
#
# error: ushort format requires 0 <= number <= 0xffff

# %%
fig = plt.figure(figsize=(15, 5))
rows = 1
col = 3

fig.add_subplot(rows, col, 1)
plt.plot(np.abs(xf), np.abs(yf))

fig.add_subplot(rows, col, 2)
plt.plot(np.abs(xf), np.abs(yf))

fig.add_subplot(rows, col, 3)

plt.plot(np.abs(xf), np.abs(yf))
plt.show()
